# %% [markdown]
# # Spectrogram

# %%
import glob, os
from obspy import read, Stream
from obspy.core.trace import Stats
import matplotlib.pyplot as plt
from matplotlib.pyplot import savefig
# %matplotlib inline

# %% [markdown]
# ### Get list of the folders

# %%
cwd = os.getcwd()

# %%
dirs = [ name for name in os.listdir(os.getcwd()) if os.path.isdir(os.path.join(os.getcwd(), name)) ]

# %% [markdown]
# ### Remove unnecessary folder

# %%
dirs.remove('.ipynb_checkpoints')

# %% [markdown]
# ### Get the list of the files inside in a folder

# %%
sacs = glob.glob(dirs[0] + '/*')

# %% [markdown]
# ## Read all sac files

# %%
st_org = Stream()
for sac in sacs:
    st_org += read(sac,format='SAC')

# %% [markdown]
# ## Spectrogram of the waveform
# [Spectrogram](https://en.wikipedia.org/wiki/Spectrogram)
# [Spectrogram in Obspy](https://docs.obspy.org/packages/autogen/obspy.imaging.spectrogram.spectrogram.html#obspy.imaging.spectrogram.spectrogram)

# %%
for tr in st:
    tr.spectrogram(log=True, title = tr.id + ' ' + str(tr.stats.starttime))

# %% [markdown]
# If you want to save the figure, add outfile = 'name_of_the_file.extention_of_the_file' inside the function. If you do not want to see the figure but just saving it, add show = False inside the function.
